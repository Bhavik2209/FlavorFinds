# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):
    try:
        title = soup.find('h1',attrs={'class':'biGQs _P egaXP rRtyp'})
        title_value = title.text
        title_string = title_value.strip()
    except AttributeError:
        title_string = ''
    return title_string

def get_address(soup):
    try:
        address = soup.find('div',attrs={'class':'biGQs _P pZUbB hmDzD'}).text
    except AttributeError:
        address=''
    return address

def get_timing(soup):
    try:
        t1 = soup.find_all('span',attrs={'class':'biGQs _P pZUbB egaXP hmDzD'})
        if(len(t1)>1):
            timing = t1[0].text + " and " + t1[1].text
        else:
            timing=''
    except AttributeError:
        timing =''
    return  timing

def get_type(soup):
    try:
        type1 = soup.find_all('div',attrs={'class' : 'biGQs _P pZUbB alXOW oCpZu GzNcM nvOhm UTQMg ZTpaU W hmDzD'})
        if(len(type1)>0):
            type = type1[0].text
        else:
            type=''
    except AttributeError:
        type =''
    return type

def get_type2(soup):
    try:
        type2 = soup.find_all('div',attrs={'class' : 'biGQs _P pZUbB alXOW oCpZu GzNcM nvOhm UTQMg ZTpaU W hmDzD'})
        if(len(type2)>1):
            type = type2[1].text
        else:
            type=''
    except AttributeError:
        type =''
    return type    

def get_description(soup):
    try:
        description1 = soup.find_all('div',attrs={'class' : 'biGQs _P pZUbB alXOW oCpZu GzNcM nvOhm UTQMg ZTpaU W hmDzD'})
        if(len(description1)>2):
            description = description1[2].text
        else:
            description=''
    except AttributeError:
        description =''
    return description

def get_phone(soup):
    try:
        phone1 = soup.find_all('span',attrs={'class' : 'biGQs _P pZUbB hmDzD'})
        if(len(phone1)>0):
            phone = phone1[-1].text
        else:
            phone=''
    except AttributeError:
        phone =''
    return phone

def get_total_ratings(soup):
    try:
        total_rating = soup.find('span',attrs={'class' : 'biGQs _P fiohW oXJmt'}).text
    except AttributeError:
        total_rating = ''
    return total_rating

def get_ratings(soup):
    try:
        rating = soup.find('span',attrs={'class' : 'biGQs _P fiohW uuBRH'}).text
    except AttributeError:
        rating = ''
    return rating

# %%
if __name__ =='__main__':
    HEADERS = ({'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",'Accept-language': 'en-US, en;q=0.5'})
    with open(r"c:\Users\SVI\Desktop\Tripadvisor.html",encoding='utf') as html:
        content = html.read()
    soup = BeautifulSoup(content,'html.parser')
    # all_names = soup.find_all('div',class_='biGQs _P fiohW ngXxk')
    # all_names.pop(0)
    # links = [a.find('a') for a in all_names]
    # filtered_links = [item for item in links if item is not None]
    all_links =[
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d801878-Reviews-Peshawri-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3664030-Reviews-Mandap-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2054651-Reviews-22nd_Parallel-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d4055043-Reviews-Canara_Coffee_House-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d801881-Reviews-WelcomCafe_Cambay-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2624294-Reviews-The_Barbeque_Nation-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2662803-Reviews-Sasumaa_Gujarati_Thali-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d8506873-Reviews-Mahakali_Sev_usal-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d1952324-Reviews-Kai_Asia-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d1064592-Reviews-Azure-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5903570-Reviews-Kansaar_Gujarati_Thali-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d8865368-Reviews-Shree_Jagdish_Farshan-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2062787-Reviews-Mandarin_Asian_Kitchen-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d4079222-Reviews-Sankalp_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3847098-Reviews-Fiorella_Italian_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d8434258-Reviews-Vishal_Sandwich-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5277909-Reviews-Gazebo_Restaurant_Vadodara-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2354259-Reviews-That_Place-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3860320-Reviews-San_s_Sizzlers-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5263632-Reviews-Tomato_s_The_Diner-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5565191-Reviews-Havmor_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3599926-Reviews-Salsa_Habanero_Mexican_Taqueria-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5908634-Reviews-Rangoli_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5905756-Reviews-Mirch_Masala_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d6499227-Reviews-Raju_Omlet-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d2523960-Reviews-Offside_Lounge-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5910564-Reviews-Shree_Kathiyawadi_Khadki-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d5901978-Reviews-Havmor_Restaurant-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3314651-Reviews-Chung_Faa-Vadodara_Vadodara_District_Gujarat.html",
    "https://www.tripadvisor.in/Restaurant_Review-g297613-d3261837-Reviews-Mirch_Masala-Vadodara_Vadodara_District_Gujarat.html"
    ]    
    d = {'title':[],'address':[],'total_ratings':[],'rating':[],'type':[],'type2':[],'description':[],'timing':[],'phone':[]}
    for link in all_links:
        new_page = requests.get(link,headers=HEADERS)
        new_soup = BeautifulSoup(new_page.content,'html.parser')
        d['title'].append(get_title(new_soup))
        d['address'].append(get_address(new_soup))
        d['timing'].append(get_timing(new_soup))
        d['type'].append(get_type(new_soup))
        d['type2'].append(get_type2(new_soup))
        d['description'].append(get_description(new_soup))
        d['phone'].append(get_phone(new_soup))
        d['total_ratings'].append(get_total_ratings(new_soup))
        d['rating'].append(get_ratings(new_soup))
    # d['total_ratings'].append(get_total_ratings(new_soup))
    page1_df = pd.DataFrame.from_dict(d)
    # amazon_df = amazon_df.dropna(subset=['title'])
    page1_df.to_csv('page1.csv',header=True,index=False)#

# %%
page1_df
# Out:
#                           title  \
# 0                      Peshawri
# 1
# 2                 22nd Parallel
# 3
# 4
# 5           The Barbeque Nation
# 6
# 7             Mahakali Sev usal
# 8                      Kai Asia
# 9                         Azure
# 10
# 11
# 12
# 13           Sankalp Restaurant
# 14  Fiorella Italian Restaurant
# 15              Vishal Sandwich
# 16
# 17                   That Place
# 18
# 19
# 20            Havmor Restaurant
# 21
# 22
# 23      Mirch Masala Restaurant
# 24
# 25
# 26     Shree Kathiyawadi Khadki
# 27            Havmor Restaurant
# 28                    Chung Faa
# 29
#
#                                               address  total_ratings rating  \
# 0       R C Dutt Road Alkapuri, Vadodara 390007 India    820 reviews    4.5
# 1
# 2   Jetalpur Rd First Floor, Tapan Complex ,Next T...    562 reviews    4.0
# 3
# 4
# 5   R C Dutt Road 3rd Floor, Shreem Shalini Mall, ...    669 reviews    4.5
# 6
# ...

# %%
if __name__ =='__main__':
    HEADERS = ({'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",'Accept-language': 'en-US, en;q=0.5'})
    with open(r"c:\Users\SVI\Desktop\Tripadvisor.html",encoding='utf') as html:
        content = html.read()
    soup = BeautifulSoup(content,'html.parser')
    # all_names = soup.find_all('div',class_='biGQs _P fiohW ngXxk')
    # all_names.pop(0)
    # links = [a.find('a') for a in all_names]
    # filtered_links = [item for item in links if item is not None]
    all_links_2= [
    '/Restaurant_Review-g297613-d3261837-Reviews-Mirch_Masala-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d2198857-Reviews-Rasthal_Gujarati_Thali-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d11869337-Reviews-Jassi_De_Parathe-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8624040-Reviews-Lalabhai_Sev_Usal-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5443046-Reviews-Hotel_Surya-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8624053-Reviews-Jay_Mahakali_Sev_Usal-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5911810-Reviews-Surya_Palace-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d3990196-Reviews-My_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8320156-Reviews-Mohanthal-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4309610-Reviews-PinXX_KIitchen_and_Lounge-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8623962-Reviews-Rajasthan_Ice_Cream_Parlour-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4471389-Reviews-Ratri_Bajar-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d801883-Reviews-Subway-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d2494193-Reviews-New_Alka-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d17519575-Reviews-Mynt-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5993579-Reviews-Sankalp_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d12659188-Reviews-The_Secret_Kitchen-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d10061918-Reviews-Meraki-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5901918-Reviews-Hariyali_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8448406-Reviews-Santushti_Shakes_and_More-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d15042969-Reviews-Old_School_Eatery-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d10040667-Reviews-Gordhan_Thal-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8624059-Reviews-Milton_s_South_Corner-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4058279-Reviews-White_Potato_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d7282320-Reviews-La_Benito-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d19392171-Reviews-Gusto_s_Pizzeria-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4107875-Reviews-Gwalia_Sweets-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d12242323-Reviews-Rasa-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8603282-Reviews-Cafe_Fitoor-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d9993618-Reviews-Gangaur_Sweets-Vadodara_Vadodara_District_Gujarat.html'
]


    
    d = {'title':[],'address':[],'total_ratings':[],'rating':[],'type':[],'type2':[],'description':[],'timing':[],'phone':[]}
    for link in all_links_2:
        new_page = requests.get("https://www.tripadvisor.in" + link,headers=HEADERS)
        new_soup = BeautifulSoup(new_page.content,'html.parser')
        d['title'].append(get_title(new_soup))
        d['address'].append(get_address(new_soup))
        d['timing'].append(get_timing(new_soup))
        d['type'].append(get_type(new_soup))
        d['type2'].append(get_type2(new_soup))
        d['description'].append(get_description(new_soup))
        d['phone'].append(get_phone(new_soup))
        d['total_ratings'].append(get_total_ratings(new_soup))
        d['rating'].append(get_ratings(new_soup))
    # d['total_ratings'].append(get_total_ratings(new_soup))
    page2_df = pd.DataFrame.from_dict(d)
    # amazon_df = amazon_df.dropna(subset=['title'])
    page2_df.to_csv('page2.csv',header=True,index=False)#

# %%
page2_df
# Out:
#                           title  \
# 0
# 1
# 2
# 3             Lalabhai Sev Usal
# 4
# 5
# 6                  Surya Palace
# 7
# 8
# 9   PinXX - KIitchen and Lounge
# 10
# 11
# 12                       Subway
# 13
# 14
# 15           Sankalp Restaurant
# 16           The Secret Kitchen
# 17                       Meraki
# 18
# 19
# 20            Old School Eatery
# 21
# 22
# 23      White Potato Restaurant
# 24                    La Benito
# 25             Gusto's Pizzeria
# 26
# 27
# 28                  Cafe Fitoor
# 29
#
#                                               address total_ratings rating  \
# 0
# 1
# 2
# 3   Mangalkirti Complex Fatehgunj, Vadodara 390002...    11 reviews    3.5
# 4
# 5
# 6   Surya Palace Lalbaug Road Near Sallam Medical,...    30 reviews    4.5
# 7
# 8
# 9       Rocv. Akota Mujhmahuda, Vadodara 390020 India    64 reviews    4.0
# 10
# 11
# 12  Shop No. 4/3 & 4/4, Govardhan Apartments Near ...    59 reviews    4.0
# 13
# 14
# ...

# %%
if __name__ =='__main__':
    HEADERS = ({'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",'Accept-language': 'en-US, en;q=0.5'})
    with open(r"c:\Users\SVI\Desktop\Tripadvisor.html",encoding='utf') as html:
        content = html.read()
    soup = BeautifulSoup(content,'html.parser')
    # all_names = soup.find_all('div',class_='biGQs _P fiohW ngXxk')
    # all_names.pop(0)
    # links = [a.find('a') for a in all_names]
    # filtered_links = [item for item in links if item is not None]
    all_links_3= [
    '/Restaurant_Review-g1152632-d5015880-Reviews-Hotel_Nyay_Mandir_Restaurant-Bharuch_Bharuch_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4909453-Reviews-Blue_Lagoon-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5909769-Reviews-Sankalp_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d7313341-Reviews-Oak_Leaf-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d9852031-Reviews-Bendys_Kitchen-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8624008-Reviews-Ramjhaniyu-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8654561-Reviews-Tasty_Vadapav-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d3458154-Reviews-New_Millennium_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5036991-Reviews-Jashan-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d25436840-Reviews-Curry_Kingdom_Vadodara-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d10535004-Reviews-Khamma_Ghani_The_Royal_Kitchens_Of_Rajasthan-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d4843258-Reviews-Barista-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d15813613-Reviews-Manmohan-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d13495239-Reviews-The_Dhaba-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d12655483-Reviews-Barbeque_Nation-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g1155996-d2457967-Reviews-Ekta_Restaurant_Banquet-Anand_Anand_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8623864-Reviews-Malayalee_Kada-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d10662356-Reviews-Simran-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d950670-Reviews-Tandoor_A_Garden_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d12876964-Reviews-22nd_Parallel-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8416551-Reviews-Havmor-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8479638-Reviews-Momoman-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d15234637-Reviews-Infi_Pizzeria-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5243305-Reviews-Orizon_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5905696-Reviews-Millennium_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5536121-Reviews-Cafe_Bistro-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8874713-Reviews-Ustad_Miyaan-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d13748420-Reviews-Le_Prive_World_Cuisine_Pizzeria-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d5908303-Reviews-Radhika_Restaurant-Vadodara_Vadodara_District_Gujarat.html',
    '/Restaurant_Review-g297613-d8449977-Reviews-Tarkari_Restaurant-Vadodara_Vadodara_District_Gujarat.html'
]



    
    d = {'title':[],'address':[],'total_ratings':[],'rating':[],'type':[],'type2':[],'description':[],'timing':[],'phone':[]}
    for link in all_links_3:
        new_page = requests.get("https://www.tripadvisor.in" + link,headers=HEADERS)
        new_soup = BeautifulSoup(new_page.content,'html.parser')
        d['title'].append(get_title(new_soup))
        d['address'].append(get_address(new_soup))
        d['timing'].append(get_timing(new_soup))
        d['type'].append(get_type(new_soup))
        d['type2'].append(get_type2(new_soup))
        d['description'].append(get_description(new_soup))
        d['phone'].append(get_phone(new_soup))
        d['total_ratings'].append(get_total_ratings(new_soup))
        d['rating'].append(get_ratings(new_soup))
    # d['total_ratings'].append(get_total_ratings(new_soup))
    page3_df = pd.DataFrame.from_dict(d)
    # amazon_df = amazon_df.dropna(subset=['title'])
    page3_df.to_csv('page3.csv',header=True,index=False)#

# %%
page3_df
# Out:
#                                              title  \
# 0                     Hotel Nyay Mandir Restaurant
# 1
# 2                               Sankalp Restaurant
# 3
# 4                                   Bendys Kitchen
# 5
# 6                                    Tasty Vadapav
# 7
# 8
# 9                           Curry Kingdom Vadodara
# 10  Khamma Ghani - The Royal Kitchens Of Rajasthan
# 11
# 12                                        Manmohan
# 13                                       The Dhaba
# 14                                 Barbeque Nation
# 15                       Ekta Restaurant & Banquet
# 16
# 17
# 18                     Tandoor A Garden Restaurant
# 19                                   22nd Parallel
# 20                                          Havmor
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 28
# 29
#
#                                               address total_ratings rating  \
# 0            8 National Highway, Bharuch 392011 India    77 reviews    4.0
# 1
# ...
